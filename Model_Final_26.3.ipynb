# %%
import cv2
import numpy as np
import os
import time
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing.image import img_to_array
from pymodbus.client import ModbusTcpClient

# %%
cam = 2

model_version = "my_model_23.1.keras"

Im_Width = 128
Im_Height = 128

Y6 = 1542 #ModBus Y6
Y4 = 1540
PLC_IP = "192.168.1.111"  #PLC's IP address
PLC_PORT = 502           # Default Modbus TCP port

# %%
def modbus(PLC_IP, PLC_PORT):

    # Create Modbus client
    client = ModbusTcpClient(PLC_IP, port=PLC_PORT)

    # Connect to the PLC
    if client.connect():
        print("Connection successful")
    else:
        print("Failed to connect to PLC")
    return client

# %%
def read_PLC_output(client, coil):
    read_result = client.read_coils(address=coil)  # Read a single coil (output)
    if read_result.isError():
        print("Read Error:", read_result)
        return None
    return read_result.bits[0]  # Return the first coil state (True for ON, False for OFF)

# %%
def write_PLC_output(client, coil,value):
    write_result = client.write_coil(address=coil, value=value)  # Write 'True' to turn ON
    if write_result.isError():
        print("Write Error:", write_result)
    else:
        print(f"Output Y6)", value)

# %%
def process_frame(frame, target_size):

    # Resize the frame to the target size
    resized_frame = cv2.resize(frame, target_size)

    # Normalize pixel values to [0, 1]
    normalized_frame = resized_frame / 255.0

    # Convert to NumPy array and add batch dimension
    frame_array = img_to_array(normalized_frame)
    frame_array = np.expand_dims(frame_array, axis=0)  # Shape: (1, height, width, channels)

    return frame_array

# %%
def predict_frame(client, frame, model, target_size):
    
    # Preprocess the frame
    frame_array = process_frame(frame, target_size)

    # Make a prediction
    predictions = model.predict(frame_array)  # Outputs probabilities for each class
    predicted_class = np.argmax(predictions[0])  # Get the index of the class with the highest probability
    confidence = predictions[0][predicted_class]  # Confidence score for the predicted class

    # Map class indices to labels
    class_labels = {0: "Defective", 2: "Non-Defective", 1: "No Bottle"}  # Update this to match your classes
    predicted_label = class_labels[predicted_class]

    prob = abs(round(confidence,2)- 0.5)*200
    print(prob)

    if ((predicted_class == 0) and (prob > 25)) :
        write_PLC_output(client, Y6, False)
        time.sleep(1)
        

    else:
        write_PLC_output(client, Y6, True)
        time.sleep(0.2)
        write_PLC_output(client, Y6, False)

    print(f"Raw Predictions: {predictions[0]}")
    print(f"Predicted Class: {predicted_label}, Confidence: {confidence:.2f}")

    return predicted_label, confidence

# %%
def capture(client, model_version, target_size=(Im_Width, Im_Height)):
    cap = cv2.VideoCapture(2)
    if not cap.isOpened():
        print("Error: Could not open the camera.")
        return

     # Load the model
    print("Loading model...") 
    model = load_model(model_version)
    print("Model loaded successfully.")
    
    output_dir = "frames"
    os.makedirs(output_dir, exist_ok=True)  # Ensure output directory exists
    frame_count = 0
    #flag = False  # Tracks the previous state of the output

    while True:
        result_Y4 = read_PLC_output(client, Y4)  # Ensure count=1 to avoid errors

        # Detect rising edge: transition from False -> True
        if result_Y4:
            write_PLC_output(client, Y6, False)
            print("TRUE - Capturing Frame")
            time.sleep(1)
            ret, frame = cap.read()
            if not ret:
                print("Error: Frame capture failed.")
                break
            
            # Save the frame
            frame_filename = os.path.join(output_dir, f"frame_{frame_count:04d}.jpg")
            cv2.imwrite(frame_filename, frame)
            print(f"Saved: {frame_filename}") 
            frame_count += 1

            predicted_label, confidence = predict_frame(client, frame, model, target_size=(Im_Width, Im_Height))

            prob = abs(round(confidence,2)- 0.5)*200
            print(f"Prediction: {predicted_label} (Confidence: {confidence:.2f})")

            # Display predicted_label on the frame
            cv2.putText(frame, f"Prediction: {predicted_label}", (10, 30),
                cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)
            cv2.putText(frame, f"Confidence: {prob:.0f}", (10, 60),
                cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)

            # Display the best frame
            cv2.imshow("Best Frame", frame)

        # Update flag to track previous state
        #flag = current_state

        # Break on 'q' key press
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

    # Release resources
    cap.release()
    cv2.destroyAllWindows()

# %%
if __name__ == "__main__":

    client = modbus(PLC_IP, PLC_PORT)
    capture(client, model_version, target_size=(Im_Width, Im_Height))
# Out:
# Connection successful
# Loading model...
# Model loaded successfully.
# Output Y6) False
# TRUE - Capturing Frame
# Saved: frames\frame_0000.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 41.999996
# Output Y6) True
# Output Y6) False
# Raw Predictions: [7.1498883e-01 8.7722560e-07 2.8501028e-01]
# Predicted Class: Defective, Confidence: 0.71
# Prediction: Defective (Confidence: 0.71)
# Output Y6) False
# TRUE - Capturing Frame
# Saved: frames\frame_0001.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step
# 27.999996
# Output Y6) True
# Output Y6) False
# Raw Predictions: [6.4009875e-01 1.9914526e-06 3.5989931e-01]
# Predicted Class: Defective, Confidence: 0.64
# Prediction: Defective (Confidence: 0.64)
# Output Y6) False
# TRUE - Capturing Frame
# Saved: frames\frame_0002.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step
# 79.99999
# Output Y6) False
# Raw Predictions: [9.0421784e-01 6.9482638e-08 9.5782034e-02]
# Predicted Class: Defective, Confidence: 0.90
# Prediction: Defective (Confidence: 0.90)
# Output Y6) False
# TRUE - Capturing Frame
# Saved: frames\frame_0003.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 82.00001
# Output Y6) False
# Raw Predictions: [9.138633e-01 5.138517e-08 8.613668e-02]
# Predicted Class: Defective, Confidence: 0.91
# Prediction: Defective (Confidence: 0.91)
# Output Y6) False
# TRUE - Capturing Frame
# Saved: frames\frame_0004.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step
# 78.0
# Output Y6) False
# Raw Predictions: [8.9233857e-01 8.4758838e-08 1.0766137e-01]
# Predicted Class: Defective, Confidence: 0.89
# Prediction: Defective (Confidence: 0.89)
# Output Y6) False
# TRUE - Capturing Frame
# Saved: frames\frame_0005.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step
# 84.0
# Output Y6) False
# Raw Predictions: [9.1622740e-01 4.6104748e-08 8.3772615e-02]
# Predicted Class: Defective, Confidence: 0.92
# Prediction: Defective (Confidence: 0.92)
# Output Y6) False
# TRUE - Capturing Frame
# Saved: frames\frame_0006.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
# 84.0
# Output Y6) False
# Raw Predictions: [9.1965073e-01 4.2366910e-08 8.0349296e-02]
# Predicted Class: Defective, Confidence: 0.92
# Prediction: Defective (Confidence: 0.92)
# Output Y6) False
# TRUE - Capturing Frame
# Saved: frames\frame_0007.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
# 79.99999
# Output Y6) False
# Raw Predictions: [9.0487719e-01 8.9310454e-08 9.5122732e-02]
# Predicted Class: Defective, Confidence: 0.90
# Prediction: Defective (Confidence: 0.90)
# Output Y6) False
# TRUE - Capturing Frame
# Saved: frames\frame_0008.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step
# 79.99999
# Output Y6) False
# Raw Predictions: [8.99111450e-01 1.09132436e-07 1.00888468e-01]
# Predicted Class: Defective, Confidence: 0.90
# Prediction: Defective (Confidence: 0.90)
# Output Y6) False
# TRUE - Capturing Frame
# Saved: frames\frame_0009.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 82.00001
# Output Y6) False
# Raw Predictions: [9.1104764e-01 5.6465090e-08 8.8952273e-02]
# Predicted Class: Defective, Confidence: 0.91
# Prediction: Defective (Confidence: 0.91)
# Output Y6) False
# TRUE - Capturing Frame
# Saved: frames\frame_0010.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
# 78.0
# Output Y6) False
# Raw Predictions: [8.9319885e-01 7.8004348e-08 1.0680107e-01]
# Predicted Class: Defective, Confidence: 0.89
# Prediction: Defective (Confidence: 0.89)
# Output Y6) False
# TRUE - Capturing Frame
# Saved: frames\frame_0011.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step
# 96.0
# Output Y6) True
# Output Y6) False
# Raw Predictions: [0.01015992 0.9770905  0.01274963]
# Predicted Class: No Bottle, Confidence: 0.98
# Prediction: No Bottle (Confidence: 0.98)
# Output Y6) False
# TRUE - Capturing Frame
# Saved: frames\frame_0012.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 98.0
# Output Y6) True
# Output Y6) False
# Raw Predictions: [0
-04]
# Predicted Class: Defective, Confidence: 1.00
# Prediction: Defective (Confidence: 1.00)
# Output Y6) False
# TRUE - Capturing Frame
# Saved: frames\frame_0065.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
# 100.0
# Output Y6) False
# Raw Predictions: [9.9985933e-01 2.2801448e-10 1.4068790e-04]
# Predicted Class: Defective, Confidence: 1.00
# Prediction: Defective (Confidence: 1.00)
# Output Y6) False
# TRUE - Capturing Frame
# Saved: frames\frame_0066.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
# 100.0
# Output Y6) False
# Raw Predictions: [9.9987972e-01 2.4241512e-10 1.2023572e-04]
# Predicted Class: Defective, Confidence: 1.00
# Prediction: Defective (Confidence: 1.00)
# Output Y6) False
# TRUE - Capturing Frame
# Saved: frames\frame_0067.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step
# 100.0
# Output Y6) False
# Raw Predictions: [9.9986625e-01 2.2218374e-10 1.3374024e-04]
# Predicted Class: Defective, Confidence: 1.00
# Prediction: Defective (Confidence: 1.00)
# Output Y6) False
# TRUE - Capturing Frame
# Saved: frames\frame_0068.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step
# 100.0
# Output Y6) False
# Raw Predictions: [9.9985361e-01 5.8550033e-11 1.4638968e-04]
# Predicted Class: Defective, Confidence: 1.00
# Prediction: Defective (Confidence: 1.00)
# Output Y6) False
# TRUE - Capturing Frame
# Saved: frames\frame_0069.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step
# 100.0
# Output Y6) False
# Raw Predictions: [9.9990785e-01 1.2099126e-10 9.2176284e-05]
# Predicted Class: Defective, Confidence: 1.00
# Prediction: Defective (Confidence: 1.00)
# Output Y6) False
# TRUE - Capturing Frame
# Saved: frames\frame_0070.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step
# 100.0
# Output Y6) False
# Raw Predictions: [9.99891400e-01 1.44145210e-10 1.08638545e-04]
# Predicted Class: Defective, Confidence: 1.00
# Prediction: Defective (Confidence: 1.00)
# Output Y6) False
# TRUE - Capturing Frame
# Saved: frames\frame_0071.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 100.0
# Output Y6) False
# Raw Predictions: [9.9986279e-01 6.7248755e-11 1.3723734e-04]
# Predicted Class: Defective, Confidence: 1.00
# Prediction: Defective (Confidence: 1.00)
# Output Y6) False
# TRUE - Capturing Frame
# Saved: frames\frame_0072.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step
# 100.0
# Output Y6) False
# Raw Predictions: [9.9988174e-01 6.4859521e-11 1.1826006e-04]
# Predicted Class: Defective, Confidence: 1.00
# Prediction: Defective (Confidence: 1.00)
# Output Y6) False
# TRUE - Capturing Frame
# Saved: frames\frame_0073.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step
# 100.0
# Output Y6) False
# Raw Predictions: [9.9991679e-01 1.0657067e-10 8.3190549e-05]
# Predicted Class: Defective, Confidence: 1.00
# Prediction: Defective (Confidence: 1.00)
# Output Y6) False
# TRUE - Capturing Frame
# Saved: frames\frame_0074.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step
# 100.0
# Output Y6) False
# Raw Predictions: [9.9891055e-01 1.4674890e-07 1.0893204e-03]
# Predicted Class: Defective, Confidence: 1.00
# Prediction: Defective (Confidence: 1.00)
# Output Y6) False
# TRUE - Capturing Frame
# Saved: frames\frame_0075.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step
# 84.0
# Output Y6) False
# Raw Predictions: [9.1628873e-01 8.2633713e-05 8.3628513e-02]
# Predicted Class: Defective, Confidence: 0.92
# Prediction: Defective (Confidence: 0.92)
# Output Y6) False
# TRUE - Capturing Frame
# Saved: frames\frame_0076.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step
# 64.0
# Output Y6) False
# Raw Predictions: [8.1629401e-01 2.8380267e-08 1.8370600e-01]
# Predicted Class: Defective, Confidence: 0.82
# Prediction: Defective (Confidence: 0.82)
# Output Y6) False
# TRUE - Capturing Frame
# Saved: frames\frame_0077.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step
# 79.99999
# Output Y6) False
# Raw Predictions: [9.0249258e-01 1.3808271e-08 9.7507402e-02]
# Predicted Class: Defective, Confidence: 0.90
# Prediction: Defective (Confidence: 0.90)
# Output Y6) False
# TRUE - Capturing Frame
# Saved: frames\frame_0078.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
# 79.99999
# Output Y6) False
# Raw Predictions: [9.0065628e-01 1.8012548e-08 9.9343769e-02]
# Predicted Class: Defective, Confidence: 0.90
# Prediction: Defective (Confidence: 0.90)
# Output Y6) False
# TRUE - Capturing Frame
# Saved: frames\frame_0079.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step
# 82.00001
# Output Y6) False
# Raw Predictions: [9.1073483e-01 1.2836682e-08 8.9265168e-02]
# Predicted Class: Defective, Confidence: 0.91
# Prediction: Defective (Confidence: 0.91)
# Output Y6) False
# TRUE - Capturing Frame
# Saved: frames\frame_0080.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step
# 79.99999
# Output Y6) False
# Raw Predictions: [8.9859623e-01 1.6807977e-08 1.0140376e-01]
# Predicted Class: Defective, Confidence: 0.90
# Prediction: Defective (Confidence: 0.90)
# Output Y6) False
# TRUE - Capturing Frame
# Saved: frames\frame_0081.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step
# 79.99999
# Output Y6) False
# Raw Predictions: [8.9568865e-01 2.0200059e-08 1.0431139e-01]
# Predicted Class: Defective, Confidence: 0.90
# Prediction: Defective (Confidence: 0.90)
# Output Y6) False
# TRUE - Capturing Frame
# Saved: frames\frame_0082.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 76.0
# Output Y6) False
# Raw Predictions: [8.7676668e-01 2.8081422e-08 1.2323336e-01]
# Predicted Class: Defective, Confidence: 0.88
# Prediction: Defective (Confidence: 0.88)
# Output Y6) False
# TRUE - Capturing Frame
# Saved: frames\frame_0083.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
# 82.00001
# Output Y6) False
# Raw Predictions: [9.082897e-01 7.600254e-09 9.171038e-02]
# Predicted Class: Defective, Confidence: 0.91
# Prediction: Defective (Confidence: 0.91)
# Output Y6) False
# TRUE - Capturing Frame
# Saved: frames\frame_0084.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step
# 60.000004
# Output Y6) False
# Raw Predictions: [7.9563516e-01 3.5662922e-08 2.0436485e-01]
# Predicted Class: Defective, Confidence: 0.80
# Prediction: Defective (Confidence: 0.80)
# Output Y6) False
# TRUE - Capturing Frame
# Saved: frames\frame_0085.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step
# 39.999996
# Output Y6) True
# Output Y6) False
# Raw Predictions: [6.99597001e-01 1.11953874e-07 3.00402880e-01]
# Predicted Class: Defective, Confidence: 0.70
# Prediction: Defective (Confidence: 0.70)
# Output Y6) False
# TRUE - Capturing Frame
# Saved: frames\frame_0086.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 44.000008
# Output Y6) True
# Output Y6) False
# Raw Predictions: [7.1632785e-01 8.0366142e-08 2.8367203e-01]
# Predicted Class: Defective, Confidence: 0.72
# Prediction: Defective (Confidence: 0.72)
# Output Y6) False
# TRUE - Capturing Frame
# Saved: frames\frame_0087.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step
# 34.000004
# Output Y6) True
# Output Y6) False
# Raw Predictions: [6.6501838e-01 5.7414198e-08 3.3498147e-01]
# Predicted Class: Defective, Confidence: 0.67
# Prediction: Defective (Confidence: 0.67)
# Output Y6) False
# TRUE - Capturing Frame
# Saved: frames\frame_0088.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step
# 5.9999943
# Output Y6) True
# Output Y6) False
# Raw Predictions: [4.6751922e-01 1.2550271e-07 5.3248060e-01]
# Predicted Class: Non-Defective, Confidence: 0.53
# Prediction: Non-Defective (Confidence: 0.53)
# Output Y6) False
# TRUE - Capturing Frame
# Saved: frames\frame_0089.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 12.0
# Output Y6) True
# Output Y6) False
# Raw Predictions: [4.3996650e-01 1.7211072e-07 5.6003332e-01]
# Predicted Class: Non-Defective, Confidence: 0.56
# Prediction: Non-Defective (Confidence: 0.56)
# Output Y6) False
# TRUE - Capturing Frame
# Saved: frames\frame_0090.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step
# 44.000008
# No response received after 3 retries, continue with next request
# ---------------------------------------------------------------------------
# ModbusIOException                         Traceback (most recent call last)
# Cell In[146], line 4
#       1 if __name__ == "__main__":
#       3     client = modbus(PLC_IP, PLC_PORT)
# ----> 4     capture(client, model_version, target_size=(Im_Width, Im_Height))
#
# Cell In[145], line 42, in capture(client, model_version, target_size)
#      39 print(f"Saved: {frame_filename}")
#      40 frame_count += 1
# ---> 42 predicted_label, confidence = predict_frame(client, frame, model, target_size=(Im_Width, Im_Height))
#      44 prob = abs(round(confidence,2)- 0.5)*200
#      45 print(f"Prediction: {predicted_label} (Confidence: {confidence:.2f})")
#
# Cell In[144], line 36, in predict_frame(client, frame, model, target_size)
#      23     write_PLC_output(client, Y6, False)
#      25 # elif predicted_class == 1:
#      26 #     write_PLC_output(client, Y6, True)
#      27 #     time.sleep(0.1)
#    (...)
#      34
#      35 else:
# ---> 36     write_PLC_output(client, Y6, True)
#      37     time.sleep(0.2)
#      38     write_PLC_output(client, Y6, False)
#
# Cell In[142], line 2, in write_PLC_output(client, coil, value)
#       1 def write_PLC_output(client, coil,value):
# ----> 2     write_result = client.write_coil(address=coil, value=value)  # Write 'True' to turn ON
#       3     if write_result.isError():
#       4         print("Write Error:", write_result)
#
# File c:\Users\malin\AppData\Local\Programs\Python\Python310\lib\site-packages\pymodbus\client\mixin.py:153, in ModbusClientMixin.write_coil(self, address, value, slave, no_response_expected)
#     140 """Write single coil (code 0x05).
#     141
#     142 :param address: Address to write to
#    (...)
#     150 Coils are addressed as 0-N (Note some device manuals uses 1-N, assuming 1==0).
#     151 """
#     152 pdu = pdu_bit.WriteSingleCoilRequest(address=address, bits=[value], dev_id=slave)
# --> 153 return self.execute(no_response_expected, pdu)
#
# File c:\Users\malin\AppData\Local\Programs\Python\Python310\lib\site-packages\pymodbus\client\base.py:186, in ModbusBaseSyncClient.execute(self, no_response_expected, request)
#     184 if not self.connect():
#     185     raise ConnectionException(f"Failed to connect[{self!s}]")
# --> 186 return self.transaction.sync_execute(no_response_expected, request)
#
# File c:\Users\malin\AppData\Local\Programs\Python\Python310\lib\site-packages\pymodbus\transaction\transaction.py:120, in TransactionManager.sync_execute(self, no_response_expected, request)
#     118 txt = f"No response received after {self.retries} retries, continue with next request"
#     119 Log.error(txt)
# --> 120 raise ModbusIOException(txt)
#
# ModbusIOException: Modbus Error: [Input/Output] No response received after 3 retries, continue with next request
