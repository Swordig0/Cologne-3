# %%
import cv2
import numpy as np
import os
import time
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing.image import img_to_array
from pymodbus.client import ModbusTcpClient

# %%
cam = 2

model_version = "my_model_23.1.keras"

Im_Width = 128
Im_Height = 128

Y6 = 1542 #ModBus Y6
Y4 = 1540
PLC_IP = "192.168.1.111"  #PLC's IP address
PLC_PORT = 502           # Default Modbus TCP port

# %%
def modbus(PLC_IP, PLC_PORT):

    # Create Modbus client
    client = ModbusTcpClient(PLC_IP, port=PLC_PORT)

    # Connect to the PLC
    if client.connect():
        print("Connection successful")
    else:
        print("Failed to connect to PLC")
    return client

# %%
def read_PLC_output(client, coil):
    read_result = client.read_coils(address=coil)  # Read a single coil (output)
    if read_result.isError():
        print("Read Error:", read_result)
        return None
    return read_result.bits[0]  # Return the first coil state (True for ON, False for OFF)

# %%
def write_PLC_output(client, coil,value):
    write_result = client.write_coil(address=coil, value=value)  # Write 'True' to turn ON
    if write_result.isError():
        print("Write Error:", write_result)
    else:
        print(f"Output Y6 turned ON (Coil {Y6})")

# %%
def process_frame(frame, target_size):

    # Resize the frame to the target size
    resized_frame = cv2.resize(frame, target_size)

    # Normalize pixel values to [0, 1]
    normalized_frame = resized_frame / 255.0

    # Convert to NumPy array and add batch dimension
    frame_array = img_to_array(normalized_frame)
    frame_array = np.expand_dims(frame_array, axis=0)  # Shape: (1, height, width, channels)

    return frame_array

# %%
def predict_frame(client, frame, model, target_size):
    
    # Preprocess the frame
    frame_array = process_frame(frame, target_size)

    # Make a prediction
    predictions = model.predict(frame_array)  # Outputs probabilities for each class
    predicted_class = np.argmax(predictions[0])  # Get the index of the class with the highest probability
    confidence = predictions[0][predicted_class]  # Confidence score for the predicted class

    # Map class indices to labels
    class_labels = {0: "Defective", 2: "Non-Defective", 1: "No Bottle"}  # Update this to match your classes
    predicted_label = class_labels[predicted_class]

    prob = abs(round(confidence,2)- 0.5)*200

    if predicted_class == 0 and prob > 50:
        write_PLC_output(client, Y6, False)
        
    # elif predicted_class == 1:
    #     write_PLC_output(client, Y6, True)
    #     time.sleep(0.1)
    #     write_PLC_output(client, Y6, False)

    # elif predicted_class == 2:
    #     write_PLC_output(client, Y6, True)
    #     time.sleep(0.1)
    #     write_PLC_output(client, Y6, False)

    else:
        write_PLC_output(client, Y6, True)
        time.sleep(0.2)
        write_PLC_output(client, Y6, False)

    print(f"Raw Predictions: {predictions[0]}")
    print(f"Predicted Class: {predicted_label}, Confidence: {confidence:.2f}")

    return predicted_label, confidence

# %%
def capture(client, model_version, target_size=(Im_Width, Im_Height)):
    cap = cv2.VideoCapture(2)
    if not cap.isOpened():
        print("Error: Could not open the camera.")
        return

     # Load the model
    print("Loading model...") 
    model = load_model(model_version)
    print("Model loaded successfully.")
    
    output_dir = "frames"
    os.makedirs(output_dir, exist_ok=True)  # Ensure output directory exists
    frame_count = 0
    #flag = False  # Tracks the previous state of the output

    while True:
        result = client.read_coils(Y4)  # Ensure count=1 to avoid errors
        if result.isError():
            print("Modbus Read Error:", result)
            continue  # Skip iteration on error

        current_state = result.bits[0]  # Read the coil status

        # Detect rising edge: transition from False -> True
        if current_state:
            print("TRUE - Capturing Frame")
            
            ret, frame = cap.read()
            if not ret:
                print("Error: Frame capture failed.")
                break
            
            # Save the frame
            frame_filename = os.path.join(output_dir, f"frame_{frame_count:04d}.jpg")
            cv2.imwrite(frame_filename, frame)
            print(f"Saved: {frame_filename}") 
            frame_count += 1

            predicted_label, confidence = predict_frame(client, frame, model, target_size=(Im_Width, Im_Height))

            prob = abs(round(confidence,2)- 0.5)*200
            print(f"Prediction: {predicted_label} (Confidence: {prob:.2f})")

            # Display predicted_label on the frame
            cv2.putText(frame, f"Prediction: {predicted_label}", (10, 30),
                cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)
            cv2.putText(frame, f"Confidence: {prob:.0f}", (10, 60),
                cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)

            # Display the best frame
            cv2.imshow("Best Frame", frame)

        # Update flag to track previous state
        #flag = current_state

        # Break on 'q' key press
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

    # Release resources
    cap.release()
    cv2.destroyAllWindows()

# %%
if __name__ == "__main__":

    client = modbus(PLC_IP, PLC_PORT)
    capture(client, model_version, target_size=(Im_Width, Im_Height))
# Out:
# Connection successful
# Loading model...
# Model loaded successfully.
# TRUE - Capturing Frame
# Saved: frames\frame_0000.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 886ms/step
# Output Y6 turned ON (Coil 1542)
# Output Y6 turned ON (Coil 1542)
# Raw Predictions: [0.35569945 0.3536091  0.2906915 ]
# Predicted Class: Defective, Confidence: 0.36
# Prediction: Defective (Confidence: 28.00)
# TRUE - Capturing Frame
# Saved: frames\frame_0001.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# Output Y6 turned ON (Coil 1542)
# Output Y6 turned ON (Coil 1542)
# Raw Predictions: [0.3227406  0.40394422 0.27331516]
# Predicted Class: No Bottle, Confidence: 0.40
# Prediction: No Bottle (Confidence: 20.00)
# TRUE - Capturing Frame
# Saved: frames\frame_0002.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# Output Y6 turned ON (Coil 1542)
# Output Y6 turned ON (Coil 1542)
# Raw Predictions: [0.47311446 0.24266218 0.28422335]
# Predicted Class: Defective, Confidence: 0.47
# Prediction: Defective (Confidence: 6.00)
# TRUE - Capturing Frame
# Saved: frames\frame_0003.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# Output Y6 turned ON (Coil 1542)
# Output Y6 turned ON (Coil 1542)
# Raw Predictions: [0.46210042 0.24281906 0.29508054]
# Predicted Class: Defective, Confidence: 0.46
# Prediction: Defective (Confidence: 8.00)
# TRUE - Capturing Frame
# Saved: frames\frame_0004.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# Output Y6 turned ON (Coil 1542)
# Output Y6 turned ON (Coil 1542)
# Raw Predictions: [0.51972455 0.18787129 0.29240415]
# Predicted Class: Defective, Confidence: 0.52
# Prediction: Defective (Confidence: 4.00)
# TRUE - Capturing Frame
# Saved: frames\frame_0005.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# Output Y6 turned ON (Coil 1542)
# Output Y6 turned ON (Coil 1542)
# Raw Predictions: [0.25855392 0.47767296 0.26377314]
# Predicted Class: No Bottle, Confidence: 0.48
# Prediction: No Bottle (Confidence: 4.00)
# TRUE - Capturing Frame
# Saved: frames\frame_0006.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# Output Y6 turned ON (Coil 1542)
# Output Y6 turned ON (Coil 1542)
# Raw Predictions: [0.23216915 0.52283585 0.24499509]
# Predicted Class: No Bottle, Confidence: 0.52
# Prediction: No Bottle (Confidence: 4.00)
# TRUE - Capturing Frame
# Saved: frames\frame_0007.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# Output Y6 turned ON (Coil 1542)
# Output Y6 turned ON (Coil 1542)
# Raw Predictions: [0.4009611  0.29992542 0.29911348]
# Predicted Class: Defective, Confidence: 0.40
# Prediction: Defective (Confidence: 20.00)
# TRUE - Capturing Frame
# Saved: frames\frame_0008.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# Output Y6 turned ON (Coil 1542)
# Output Y6 turned ON (Coil 1542)
# Raw Predictions: [0.47202536 0.2256911  0.30228359]
# Predicted Class: Defective, Confidence: 0.47
# Prediction: Defective (Confidence: 6.00)
# TRUE - Capturing Frame
# Saved: frames\frame_0009.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# Output Y6 turned ON (Coil 1542)
# Output Y6 turned ON (Coil 1542)
# Raw Predictions: [0.43115285 0.27676558 0.29208156]
# Predicted Class: Defective, Confidence: 0.43
# Prediction: Defective (Confidence: 14.00)
# TRUE - Capturing Frame
# Saved: frames\frame_0010.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# Output Y6 turned ON (Coil 1542)
# Output Y6 turned ON (Coil 1542)
# Raw Predictions: [0.4468413  0.25621325 0.2969454 ]
# Predicted Class: Defective, Confidence: 0.45
# Prediction: Defective (Confidence: 10.00)
# TRUE - Capturing Frame
# Saved: frames\frame_0011.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# Output Y6 turned ON (Coil 1542)
# Output Y6 turned ON (Coil 1542)
# Raw Predictions: [0.24271238 0.50365794 0.25362965]
# Predicted Class: No Bottle, Confidence: 0.50
# Prediction: No Bottle (Confidence: 0.00)
# TRUE - Capturing Frame
# Saved: frames\frame_0012.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# Output Y6 turned ON (Coil 1542)
# Output Y6 turned ON (Coil 1542)
# Raw Predictions: [0.3818945  0.33545092 0.2826546 ]
# Predicted Class: Defective, Confidence: 0.38
# Prediction: Defective (Confidence: 24.00)
# TRUE - Capturing Frame
# Saved: frames\frame_0013.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# Output Y6 turned ON (Coil 1542)
# Output Y6 turned ON (Coil 1542)
# Raw Predictions: [0.30774865 0.40799186 0.28425953]
# Predicted Class: No Bottle, Confidence: 0.41
# Prediction: No Bottle (Confidence: 18.00)
# TRUE - Capturing Frame
# Saved: frames\frame_0014.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# Output Y6 turned ON (Coil 1542)
# Output Y6 turned ON (Coil 1542)
# Raw Predictions: [0.59165883 0.13416992 0.27417126]
# Predicted Class: Defective, Confidence: 0.59
# Prediction: Defective (Confidence: 18.00)
# TRUE - Capturing Frame
# Saved: frames\frame_
00)
# TRUE - Capturing Frame
# Saved: frames\frame_0211.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# Output Y6 turned ON (Coil 1542)
# Raw Predictions: [9.7535217e-01 5.7180449e-07 2.4647292e-02]
# Predicted Class: Defective, Confidence: 0.98
# Prediction: Defective (Confidence: 96.00)
# TRUE - Capturing Frame
# Saved: frames\frame_0212.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# Output Y6 turned ON (Coil 1542)
# Raw Predictions: [9.6565217e-01 1.2562680e-05 3.4335244e-02]
# Predicted Class: Defective, Confidence: 0.97
# Prediction: Defective (Confidence: 94.00)
# TRUE - Capturing Frame
# Saved: frames\frame_0213.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# Output Y6 turned ON (Coil 1542)
# Raw Predictions: [0.880829   0.00134881 0.11782224]
# Predicted Class: Defective, Confidence: 0.88
# Prediction: Defective (Confidence: 76.00)
# TRUE - Capturing Frame
# Saved: frames\frame_0214.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# Output Y6 turned ON (Coil 1542)
# Raw Predictions: [0.7457165  0.0127032  0.24158035]
# Predicted Class: Defective, Confidence: 0.75
# Prediction: Defective (Confidence: 50.00)
# TRUE - Capturing Frame
# Saved: frames\frame_0215.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# Output Y6 turned ON (Coil 1542)
# Output Y6 turned ON (Coil 1542)
# Raw Predictions: [0.48681173 0.11543584 0.39775246]
# Predicted Class: Defective, Confidence: 0.49
# Prediction: Defective (Confidence: 2.00)
# TRUE - Capturing Frame
# Saved: frames\frame_0216.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# Output Y6 turned ON (Coil 1542)
# Output Y6 turned ON (Coil 1542)
# Raw Predictions: [0.5006863  0.12982829 0.3694854 ]
# Predicted Class: Defective, Confidence: 0.50
# Prediction: Defective (Confidence: 0.00)
# TRUE - Capturing Frame
# Saved: frames\frame_0217.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# Output Y6 turned ON (Coil 1542)
# Raw Predictions: [7.1904141e-01 2.3435599e-07 2.8095835e-01]
# Predicted Class: Defective, Confidence: 0.72
# Prediction: Defective (Confidence: 44.00)
# TRUE - Capturing Frame
# Saved: frames\frame_0218.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# Output Y6 turned ON (Coil 1542)
# Raw Predictions: [9.8871136e-01 2.7307783e-08 1.1288575e-02]
# Predicted Class: Defective, Confidence: 0.99
# Prediction: Defective (Confidence: 98.00)
# TRUE - Capturing Frame
# Saved: frames\frame_0219.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# Output Y6 turned ON (Coil 1542)
# Output Y6 turned ON (Coil 1542)
# Raw Predictions: [1.7147575e-01 1.2605064e-04 8.2839823e-01]
# Predicted Class: Non-Defective, Confidence: 0.83
# Prediction: Non-Defective (Confidence: 66.00)
# TRUE - Capturing Frame
# Saved: frames\frame_0220.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# Output Y6 turned ON (Coil 1542)
# Output Y6 turned ON (Coil 1542)
# Raw Predictions: [2.0542628e-01 7.1287701e-05 7.9450238e-01]
# Predicted Class: Non-Defective, Confidence: 0.79
# Prediction: Non-Defective (Confidence: 58.00)
# TRUE - Capturing Frame
# Saved: frames\frame_0221.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# Output Y6 turned ON (Coil 1542)
# Output Y6 turned ON (Coil 1542)
# Raw Predictions: [0.5438604  0.12579365 0.330346  ]
# Predicted Class: Defective, Confidence: 0.54
# Prediction: Defective (Confidence: 8.00)
# TRUE - Capturing Frame
# Saved: frames\frame_0222.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# Output Y6 turned ON (Coil 1542)
# Output Y6 turned ON (Coil 1542)
# Raw Predictions: [4.0995908e-01 1.2440267e-06 5.9003967e-01]
# Predicted Class: Non-Defective, Confidence: 0.59
# Prediction: Non-Defective (Confidence: 18.00)
# TRUE - Capturing Frame
# Saved: frames\frame_0223.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# Output Y6 turned ON (Coil 1542)
# Raw Predictions: [9.82833087e-01 1.39365905e-08 1.71669386e-02]
# Predicted Class: Defective, Confidence: 0.98
# Prediction: Defective (Confidence: 96.00)
# TRUE - Capturing Frame
# Saved: frames\frame_0224.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# Output Y6 turned ON (Coil 1542)
# Raw Predictions: [9.6133000e-01 3.4764303e-09 3.8669989e-02]
# Predicted Class: Defective, Confidence: 0.96
# Prediction: Defective (Confidence: 92.00)
# TRUE - Capturing Frame
# Saved: frames\frame_0225.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# Output Y6 turned ON (Coil 1542)
# Raw Predictions: [9.5016408e-01 4.3183995e-08 4.9835905e-02]
# Predicted Class: Defective, Confidence: 0.95
# Prediction: Defective (Confidence: 90.00)
# TRUE - Capturing Frame
# Saved: frames\frame_0226.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# Output Y6 turned ON (Coil 1542)
# Output Y6 turned ON (Coil 1542)
# Raw Predictions: [0.33833465 0.31584176 0.34582365]
# Predicted Class: Non-Defective, Confidence: 0.35
# Prediction: Non-Defective (Confidence: 30.00)
# TRUE - Capturing Frame
# Saved: frames\frame_0227.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# Output Y6 turned ON (Coil 1542)
# Output Y6 turned ON (Coil 1542)
# Raw Predictions: [0.31637993 0.3365725  0.3470476 ]
# Predicted Class: Non-Defective, Confidence: 0.35
# Prediction: Non-Defective (Confidence: 30.00)
# TRUE - Capturing Frame
# Saved: frames\frame_0228.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# Output Y6 turned ON (Coil 1542)
# Output Y6 turned ON (Coil 1542)
# Raw Predictions: [5.4249567e-01 6.6471057e-07 4.5750377e-01]
# Predicted Class: Defective, Confidence: 0.54
# Prediction: Defective (Confidence: 8.00)
# TRUE - Capturing Frame
# Saved: frames\frame_0229.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# Output Y6 turned ON (Coil 1542)
# Raw Predictions: [9.7124386e-01 1.4121333e-07 2.8756017e-02]
# Predicted Class: Defective, Confidence: 0.97
# Prediction: Defective (Confidence: 94.00)
# TRUE - Capturing Frame
# Saved: frames\frame_0230.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# Output Y6 turned ON (Coil 1542)
# Raw Predictions: [9.8859978e-01 1.5953354e-08 1.1400286e-02]
# Predicted Class: Defective, Confidence: 0.99
# Prediction: Defective (Confidence: 98.00)
